# %%
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Keyword_09_05_2021= pd.read_csv('keyword_09052021.csv',skiprows=1)

# %%
Keyword_09_05_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Department             1000000 non-null  object
#  1   Search Term            999997 non-null   object
#  2   Search Frequency Rank  1000000 non-null  object
#  3   #1 Clicked ASIN        1000000 non-null  object
#  4   #1 Product Title       999973 non-null   object
#  5   #1 Click Share         1000000 non-null  object
#  6   #1 Conversion Share    1000000 non-null  object
#  7   #2 Clicked ASIN        994751 non-null   object
#  8   #2 Product Title       994657 non-null   object
#  9   #2 Click Share         1000000 non-null  object
#  10  #2 Conversion Share    1000000 non-null  object
#  11  #3 Clicked ASIN        967937 non-null   object
#  12  #3 Product Title       967799 non-null   object
#  13  #3 Click Share         1000000 non-null  object
# ...

# %%
Keyword_09_05_2021.head(5)
# Out:
#    Department            Search Term Search Frequency Rank #1 Clicked ASIN  \
# 0  Amazon.com  disposable face masks                     1      B08GSK4VK5
# 1  Amazon.com              face mask                     2      B088C2WD5F
# 2  Amazon.com                 pop it                     3      B0915TWDD3
# 3  Amazon.com                   desk                     4      B07FKWT7HS
# 4  Amazon.com                earbuds                     5      B07J2Z5DBM
#
#                                     #1 Product Title #1 Click Share  \
# 0  Black Face Mask,100pcs Disposable Masks Breath...          7.48%
# 1  EnerPlex 3-Ply Reusable Face Mask - Breathable...          8.53%
# 2  LANQKUISZ Pop Push its tie dye Bubble Sensory ...          4.67%
# 3  FURINNO Econ Multipurpose Home Office Computer...          9.19%
# 4  TOZO T10 Bluetooth 5.0 Wireless Earbuds with W...         10.49%
#
#   #1 Conversion Share #2 Clicked ASIN  \
# 0               7.91%      B088RM13B3
# ...

# %%
list(Keyword_09_05_2021)
# Out:
# ['Department',
#  'Search Term',
#  'Search Frequency Rank',
#  '#1 Clicked ASIN',
#  '#1 Product Title',
#  '#1 Click Share',
#  '#1 Conversion Share',
#  '#2 Clicked ASIN',
#  '#2 Product Title',
#  '#2 Click Share',
#  '#2 Conversion Share',
#  '#3 Clicked ASIN',
#  '#3 Product Title',
#  '#3 Click Share',
#  '#3 Conversion Share']

# %%
len(Keyword_09_05_2021)
# Out:
# 1000000

# %%
Keyword_09_05_2021.shape
# Out:
# (1000000, 15)

# %%
Keyword_09_05_2021.dropna()[Keyword_09_05_2021.dropna()['Search Term'].str.contains('cooler')]
# Out:
#         Department             Search Term Search Frequency Rank  \
# 515     Amazon.com                  cooler                   516
# 1057    Amazon.com             yeti cooler                 1,058
# 3575    Amazon.com      cooler with wheels                 3,576
# 4297    Amazon.com             rtic cooler                 4,298
# 4335    Amazon.com           igloo coolers                 4,336
# ...            ...                     ...                   ...
# 995845  Amazon.com             5 qt cooler               995,846
# 997484  Amazon.com       cooler small hard               997,485
# 997489  Amazon.com  citrus cooler gatorade               997,490
# 997710  Amazon.com        otter box cooler               997,711
# 999389  Amazon.com            intex cooler               999,390
#
#        #1 Clicked ASIN                                   #1 Product Title  \
# 515         B00AU6G4QS  Coleman Rolling Cooler | 50 Quart Xtreme 5 Day...
# ...

# %%
Keyword_09_05_2021.isna().sum()
# Out:
# Department                   0
# Search Term                  3
# Search Frequency Rank        0
# #1 Clicked ASIN              0
# #1 Product Title            27
# #1 Click Share               0
# #1 Conversion Share          0
# #2 Clicked ASIN           5249
# #2 Product Title          5343
# #2 Click Share               0
# #2 Conversion Share          0
# #3 Clicked ASIN          32063
# #3 Product Title         32201
# #3 Click Share               0
# #3 Conversion Share          0
# dtype: int64

# %%
Keyword_09_05_2021.isna().sum().reset_index(name="n").plot.bar(x='index', y='n', rot=50)
# Out:
# <AxesSubplot:xlabel='index'>

# %%
Keyword_09_05_2021 = Keyword_09_05_2021.fillna('N/A')

# %%
Keyword_09_05_2021.isna().sum()
# Out:
# Department               0
# Search Term              0
# Search Frequency Rank    0
# #1 Clicked ASIN          0
# #1 Product Title         0
# #1 Click Share           0
# #1 Conversion Share      0
# #2 Clicked ASIN          0
# #2 Product Title         0
# #2 Click Share           0
# #2 Conversion Share      0
# #3 Clicked ASIN          0
# #3 Product Title         0
# #3 Click Share           0
# #3 Conversion Share      0
# dtype: int64

# %%
Keyword_09_05_2021.isna().sum().reset_index(name="n").plot.bar(x='index', y='n', rot=50)
# Out:
# <AxesSubplot:xlabel='index'>

# %%
Cooler_09_05_2021 = Keyword_09_05_2021[Keyword_09_05_2021['Search Term'].str.contains('cooler')][['Search Term','Search Frequency Rank']]

# %%
Keyword_09_05_2021[Keyword_09_05_2021['Search Term'].str.contains('cooler')][['Search Term','Search Frequency Rank']]
# Out:
#                    Search Term Search Frequency Rank
# 515                     cooler                   516
# 1057               yeti cooler                 1,058
# 3575        cooler with wheels                 3,576
# 4297               rtic cooler                 4,298
# 4335             igloo coolers                 4,336
# ...                        ...                   ...
# 995845             5 qt cooler               995,846
# 997484       cooler small hard               997,485
# 997489  citrus cooler gatorade               997,490
# 997710        otter box cooler               997,711
# 999389            intex cooler               999,390
#
# [1345 rows x 2 columns]

# %%
Keyword_09_05_2021['Search Term'].str.contains('N/A').sum()
# Out:
# 3

# %%
Keyword_09_05_2021
# Out:
#         Department               Search Term Search Frequency Rank  \
# 0       Amazon.com     disposable face masks                     1
# 1       Amazon.com                 face mask                     2
# 2       Amazon.com                    pop it                     3
# 3       Amazon.com                      desk                     4
# 4       Amazon.com                   earbuds                     5
# ...            ...                       ...                   ...
# 999995  Amazon.com      true skin suture kit               999,996
# 999996  Amazon.com   purple bandanas 12 pack               999,997
# 999997  Amazon.com         shaping underwear               999,998
# 999998  Amazon.com       water proof dog bed               999,999
# 999999  Amazon.com  something borrowed movie             1,000,000
#
#        #1 Clicked ASIN                                   #1 Product Title  \
# 0           B08GSK4VK5  Black Face Mask,100pcs Disposable Masks Breath...
# ...

# %%
Cooler_09_05_2021 = Keyword_09_05_2021[~Keyword_09_05_2021['Search Term'].str.contains('N/A')
# Out:
#   File "<ipython-input-165-bcd0900e4e1f>", line 1
#     Cooler_09_05_2021 = Keyword_09_05_2021[~Keyword_09_05_2021['Search Term'].str.contains('N/A')
#                                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
Cooler_09_05_2021['day'] = '2021-09-05'

# %%
Cooler_09_05_2021
# Out:
#                    Search Term Search Frequency Rank         day
# 515                     cooler                   516  2021-09-05
# 1057               yeti cooler                 1,058  2021-09-05
# 3575        cooler with wheels                 3,576  2021-09-05
# 4297               rtic cooler                 4,298  2021-09-05
# 4335             igloo coolers                 4,336  2021-09-05
# ...                        ...                   ...         ...
# 995845             5 qt cooler               995,846  2021-09-05
# 997484       cooler small hard               997,485  2021-09-05
# 997489  citrus cooler gatorade               997,490  2021-09-05
# 997710        otter box cooler               997,711  2021-09-05
# 999389            intex cooler               999,390  2021-09-05
#
# [1345 rows x 3 columns]

# %%
Cooler_09_05_2021 = Cooler_09_05_2021[Cooler_09_05_2021['Search Term'] == 'cooler']

# %%
Keyword_08_22_2021= pd.read_csv('keyword_08222021.csv',skiprows=1)

# %%
Cooler_08_22_2021 = Keyword_08_22_2021[Keyword_08_22_2021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]

# %%
Cooler_08_22_2021['day'] = '2021-08-22'

# %%
Cooler_08_22_2021
# Out:
#   Search Term Search Frequency Rank         day
# 0      cooler                   516  2021-08-22

# %%
Cooler_09_05_2021
# Out:
#     Search Term Search Frequency Rank         day
# 515      cooler                   516  2021-09-05

# %%
df1 = pd.concat([Cooler_08_22_2021,Cooler_09_05_2021])

# %%
keyword_08152021= pd.read_csv('keyword_08152021.csv',skiprows=1)
Cooler_08_15_2021 = keyword_08152021[keyword_08152021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_08_15_2021['day'] = '2021-08-15'

# %%
df1 = pd.concat([df1,Cooler_08_15_2021])

# %%
df1
# Out:
#     Search Term Search Frequency Rank         day
# 0        cooler                   516  2021-08-22
# 515      cooler                   516  2021-09-05
# 0        cooler                   494  2021-08-15

# %%
keyword_08082021= pd.read_csv('keyword_08082021.csv',skiprows=1)
Cooler_08_08_2021 = keyword_08082021[keyword_08082021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_08_08_2021['day'] = '2021-08-08'
df1 = pd.concat([df1,Cooler_08_08_2021])

# %%
df1.sort_values('day',ascending = True)
# Out:
#     Search Term Search Frequency Rank         day
# 0        cooler                   401  2021-08-08
# 0        cooler                   494  2021-08-15
# 0        cooler                   516  2021-08-22
# 515      cooler                   516  2021-09-05

# %%
keyword_07312021= pd.read_csv('keyword_07312021.csv',skiprows=1)
Cooler_07_31_2021 = keyword_07312021[keyword_07312021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_07_31_2021['day'] = '2021-07-31'
df1 = pd.concat([df1,Cooler_07_31_2021])

# %%
df1.sort_values('day',ascending = True)
# Out:
#     Search Term Search Frequency Rank         day
# 0        cooler                   243  2021-07-31
# 0        cooler                   401  2021-08-08
# 0        cooler                   494  2021-08-15
# 0        cooler                   516  2021-08-22
# 515      cooler                   516  2021-09-05

# %%
keyword_07242021= pd.read_csv('keyword_07242021.csv',skiprows=1)
Cooler_07_24_2021 = keyword_07242021[keyword_07242021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_07_24_2021['day'] = '2021-07-24'
df1 = pd.concat([df1,Cooler_07_24_2021])

# %%
df1.sort_values('day',ascending = True)
# Out:
#     Search Term Search Frequency Rank         day
# 0        cooler                   186  2021-07-24
# 0        cooler                   243  2021-07-31
# 0        cooler                   401  2021-08-08
# 0        cooler                   494  2021-08-15
# 0        cooler                   516  2021-08-22
# 515      cooler                   516  2021-09-05

# %%
keyword_07172021= pd.read_csv('keyword_07172021.csv',skiprows=1)
Cooler_07172021 = keyword_07172021[keyword_07172021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_07172021['day'] = '2021-07-17'
df1 = pd.concat([df1,Cooler_07172021])

# %%
keyword_07102021= pd.read_csv('keyword_07102021.csv',skiprows=1)
Cooler_07102021 = keyword_07102021[keyword_07102021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_07102021['day'] = '2021-07-10'
df1 = pd.concat([df1,Cooler_07102021])

# %%
keyword_07032021= pd.read_csv('keyword_07032021.csv',skiprows=1)
Cooler_07032021 = keyword_07032021[keyword_07032021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_07032021['day'] = '2021-07-03'
df1 = pd.concat([df1,Cooler_07032021])

# %%
df1.sort_values('day',ascending = True)
# Out:
#     Search Term Search Frequency Rank         day
# 0        cooler                   109  2021-07-03
# 0        cooler                   132  2021-07-10
# 0        cooler                   186  2021-07-24
# 0        cooler                   243  2021-07-31
# 0        cooler                   401  2021-08-08
# 0        cooler                   494  2021-08-15
# 0        cooler                   516  2021-08-22
# 515      cooler                   516  2021-09-05

# %%
keyword_06262021= pd.read_csv('keyword_06262021.csv',skiprows=1)
Cooler_06262021 = keyword_06262021[keyword_06262021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_06262021['day'] = '2021-06-26'
df1 = pd.concat([df1,Cooler_06262021])

# %%
keyword_06192021= pd.read_csv('keyword_06192021.csv',skiprows=1)
Cooler_06192021 = keyword_06192021[keyword_06192021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_06192021['day'] = '2021-06-19'
df1 = pd.concat([df1,Cooler_06192021])

# %%
keyword_06122021= pd.read_csv('keyword_06122021.csv',skiprows=1)
Cooler_06122021 = keyword_06122021[keyword_06122021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_06122021['day'] = '2021-06-12'
df1 = pd.concat([df1,Cooler_06122021])

# %%
keyword_06052021= pd.read_csv('keyword_06052021.csv',skiprows=1)
Cooler_06052021 = keyword_06052021[keyword_06052021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_06052021['day'] = '2021-06-05'
df1 = pd.concat([df1,Cooler_06052021])

# %%
keyword_05292021= pd.read_csv('keyword_05292021.csv',skiprows=1)
Cooler_05292021 = keyword_05292021[keyword_05292021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_05292021['day'] = '2021-05-29'
df1 = pd.concat([df1,Cooler_05292021])

# %%
keyword_05222021= pd.read_csv('keyword_05222021.csv',skiprows=1)
Cooler_05222021 = keyword_05222021[keyword_05222021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_05222021['day'] = '2021-05-22'
df1 = pd.concat([df1,Cooler_05222021])

# %%
keyword_05082021= pd.read_csv('keyword_05082021.csv',skiprows=1)
Cooler_05082021 = keyword_05082021[keyword_05082021['Search Term'] == 'cooler'][['Search Term','Search Frequency Rank']]
Cooler_05082021['day'] = '2021-05-18'
df1 = pd.concat([df1,Cooler_05082021])

# %%
df1 = df1.sort_values('day',ascending = True)

# %%
df1['sort'] = df1.day.rank(ascending = True)

# %%
df1
# Out:
#     Search Term Search Frequency Rank         day  sort
# 0        cooler                   355  2021-05-15   1.0
# 0        cooler                   393  2021-05-18   2.0
# 0        cooler                   248  2021-05-22   3.0
# 0        cooler                   169  2021-05-29   4.0
# 0        cooler                   135  2021-06-12   5.0
# 0        cooler                   105  2021-06-19   6.0
# 0        cooler                   128  2021-06-26   7.0
# 0        cooler                   109  2021-07-03   8.0
# 0        cooler                   132  2021-07-10   9.0
# 0        cooler                   186  2021-07-24  10.0
# 0        cooler                   243  2021-07-31  11.0
# 0        cooler                   401  2021-08-08  12.0
# 0        cooler                   494  2021-08-15  13.0
# 0        cooler                   516  2021-08-22  14.0
# 515      cooler                   516  2021-09-05  15.0

# %%
df1['Search Frequency Rank']= df1['Search Frequency Rank'].astype(str).astype(int)

# %%
sns.scatterplot(data=df1, x="sort", y="Search Frequency Rank")
# Out:
# <AxesSubplot:xlabel='sort', ylabel='Search Frequency Rank'>
